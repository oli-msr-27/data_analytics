# %% [markdown]
# ## Welcome to my first Jupyter Notebook

# %% [markdown]
# <table>
#   <tr><th>Cell Type</th><th>Purpose</th></tr>
#   <tr><td>Code</td><td>Runs Python code</td></tr>
#   <tr><td>Markdown</td><td>Formatted text, headings, tables, images</td></tr>
#   <tr><td>Raw</td><td>Content passed through unmodified, not executed or rendered</td></tr>
# </table>

# %%
name = "Oliver"
print(f"Welcome to the Data Analytics course, {name}!")
# Out:
# Welcome to the Data Analytics course, Oliver!
